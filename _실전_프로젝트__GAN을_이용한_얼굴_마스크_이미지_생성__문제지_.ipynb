# %% [markdown]
# <a href="https://colab.research.google.com/github/cestclaire/programmers_project_results/blob/main/_%EC%8B%A4%EC%A0%84_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8__GAN%EC%9D%84_%EC%9D%B4%EC%9A%A9%ED%95%9C_%EC%96%BC%EA%B5%B4_%EB%A7%88%EC%8A%A4%ED%81%AC_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%83%9D%EC%84%B1__%EB%AC%B8%EC%A0%9C%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <b>실전 프로젝트 - GAN을 이용한 얼굴 마스크 이미지 생성 </b>
#
# * 마스크를 착용한 이미지와 마스크를 착용하지 않은 얼굴 이미지를 생성하는 <b>생성 모델</b>을 만드세요.
# * 다음의 두 가지 대표적인 GAN 모델을 실습합니다.
#     1. [Generative Adversarial Networks (NIPS 2014)](https://arxiv.org/abs/1406.2661)
#     2. [Deep Convolutional Generative Adversarial Networks (ICLR 2016)](https://arxiv.org/abs/1511.06434)
# * 또한 자신이 원하는 아키텍처의 GAN 모델을 직접 선택하여 학습하는 실습을 진행합니다.
# * 본 프로젝트는 <b>최종적으로 높은 점수(score)를 얻는 것이 목표</b>입니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
# * 최종적으로 <b>팀 단위로 제출할 파일</b>은 다음과 같습니다.
#     1. PPT 파일: 사용한 모델과 최종적인 FID 점수에 대한 설명을 포함하기
#     2. Colab Notebook 파일: <b>[파일]</b> - <b>[다운로드]</b> - <b>[.ipynb 다운로드]</b>
#     3. 최종 결과 이미지(마스크 착용 1,000개 및 마스크 미착용 1,000개)가 포함된 압축 파일
# * 자세한 평가 기준은 <b>Problem 1</b>에서 확인하세요.

# %% [markdown]
# #### <b>(알아보기) 데이터셋 다운로드</b>
#
# * 실습을 위해 [<b>Face Mask Classification</b> 데이터셋](https://github.com/ndb796/Face-Mask-Classification-20000-Dataset)을 불러옵니다.
# * 데이터셋은 흑백(grayscale) 이미지로 구성됩니다.
# * GPU 가속기를 이용하기 위해 <b>[런타임]</b> - <b>[런타임 유형 변경]</b> - <b>[GPU]</b>를 선택합니다.
# * <b>학습 데이터셋</b>
#     * 마스크 착용(with mask): 9,000장
#     * 마스크 미착용(wihtout mask): 9,000장
# * <b>테스트 데이터셋</b>
#     * 마스크 착용(with mask): 1,000장
#     * 마스크 미착용(wihtout mask): 1,000장

# %%
# !git clone https://github.com/ndb796/Face-Mask-Classification-20000-Dataset
# Out:
# Cloning into 'Face-Mask-Classification-20000-Dataset'...
# remote: Enumerating objects: 20017, done.
# remote: Total 20017 (delta 0), reused 0 (delta 0), pack-reused 20017
# Receiving objects: 100% (20017/20017), 600.78 MiB | 15.49 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Checking out files: 100% (20001/20001), done.

# %% [markdown]
# #### <b>(알아보기) 필요한 라이브러리 불러오기</b>
#
# * 실습을 위한 PyTorch 라이브러리를 불러옵니다.

# %%
import os
import time
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %% [markdown]
# #### <b>(알아보기) 학습 이미지 시각화</b>
#
# * 학습할 이미지 중에서 원하는 이미지를 골라 시각화합니다.

# %%
# 마스크를 쓴 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/with_mask/with-mask-default-mask-seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()

# 마스크를 쓰지 않은 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/without_mask/seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()
# Out:
# 이미지 크기: (224, 224)
# 이미지 크기: (224, 224)

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * 학습할 이미지 크기: 1 X 64 X 64

# %%
transforms_train = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.Grayscale(1),
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)) # normalization
])

data_dir = './Face-Mask-Classification-20000-Dataset/'
train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
print('Train dataset size:', len(train_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Train dataset size: 18000
# Class names: ['with_mask', 'without_mask']

# %% [markdown]
# #### <b>(알아보기) 기본적인 GAN 실습 - 모델 정의</b>
#
# * 논문 제목: [Generative Adversarial Networks](https://arxiv.org/abs/1406.2661) <b>(NIPS 2014)</b>
# * 가장 기본적인 GAN 모델을 학습해보는 실습을 진행합니다.
#     * 마스크 착용 여부를 선택하기 위해 <b>조건부(conditional) GAN</b>을 이용합니다.
#     * <b>Reference</b>: [Conditional Generative Adversarial Nets (2014)](https://arxiv.org/abs/1411.1784)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 생성자(Generator) 및 판별자(Discriminator) 모델을 정의합니다.
#     * 생성자 클래스: SimpleGenerator
#     * 판별자 클래스: SimpleDiscriminator
# * 본 소스코드는 원본 논문에서 제안한 아키텍처와 유사한 아키텍처를 이용합니다.
# * <b>Reference</b>: [PyTorch GAN 예시 코드](https://github.com/eriklindernoren/PyTorch-GAN/blob/master/implementations/gan/gan.py)

# %%
latent_dim = 100
n_classes = 2


# 생성자(Generator) 클래스 정의
class SimpleGenerator(nn.Module):
    def __init__(self):
        super(SimpleGenerator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        # 하나의 블록(block) 정의
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                # 배치 정규화(batch normalization) 수행(차원 동일)
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # 생성자 모델은 연속적인 여러 개의 블록을 가짐
        self.model = nn.Sequential(
            *block(latent_dim + n_classes, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            *block(1024, 2048),
            nn.Linear(2048, 1 * 64 * 64),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # 노이즈(noise) 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((noise, self.label_embed(labels)), -1)
        img = self.model(inputs)
        img = img.view(img.size(0), 1, 64, 64)
        return img


# 판별자(Discriminator) 클래스 정의
class SimpleDiscriminator(nn.Module):
    def __init__(self):
        super(SimpleDiscriminator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        self.model = nn.Sequential(
            nn.Linear(1 * 64 * 64 + n_classes, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 1),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        flattened = img.view(img.size(0), -1)
        # 이미지 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((flattened, self.label_embed(labels)), -1)
        output = self.model(inputs)

        return output

# %% [markdown]
# #### <b>(알아보기) 기본적인 GAN 실습 - 모델 학습 및 샘플링</b>
#
# * 학습을 위해 생성자와 판별자 모델을 초기화합니다.
# * 적절한 하이퍼 파라미터를 설정합니다.

# %%
# 생성자(generator)와 판별자(discriminator) 초기화
simple_generator = SimpleGenerator()
simple_discriminator = SimpleDiscriminator()

simple_generator.cuda()
simple_discriminator.cuda()

# 손실 함수(loss function)
adversarial_loss = nn.MSELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0002

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(simple_generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(simple_discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# * 모델을 학습하면서 주기적으로 샘플링하여 결과를 확인할 수 있습니다.

# %%
# !mkdir -p ./results/simple/

n_epochs = 100 # 학습의 횟수(epoch) 설정
sample_interval = 500 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(train_dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()
        labels = labels.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()
        generated_labels = torch.randint(0, n_classes, (imgs.shape[0],)).cuda()

        # 이미지 생성
        generated_imgs = simple_generator(z, generated_labels)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(simple_discriminator(generated_imgs, generated_labels), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(simple_discriminator(real_imgs, labels), real)
        fake_loss = adversarial_loss(simple_discriminator(generated_imgs.detach(), generated_labels), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(train_dataloader) + i
        if done % sample_interval == 0:
            # 클래스당 8개의 이미지를 생성하여 2 X 8 격자 이미지에 출력
            z = torch.normal(mean=0, std=1, size=(n_classes * 8, latent_dim)).cuda()
            labels = torch.LongTensor([i for i in range(n_classes) for _ in range(8)]).cuda()
            generated_imgs = simple_generator(z, labels)
            save_image(generated_imgs, f"./results/simple/{done}.png", nrow=8, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/100] [D loss: 0.137367] [G loss: 0.470136] [Elapsed time: 23.66s]
# [Epoch 1/100] [D loss: 0.125238] [G loss: 0.365138] [Elapsed time: 43.95s]
# [Epoch 2/100] [D loss: 0.152340] [G loss: 0.591201] [Elapsed time: 65.07s]
# [Epoch 3/100] [D loss: 0.162686] [G loss: 0.605926] [Elapsed time: 85.47s]
# [Epoch 4/100] [D loss: 0.128126] [G loss: 0.578441] [Elapsed time: 105.95s]
# [Epoch 5/100] [D loss: 0.211859] [G loss: 0.353405] [Elapsed time: 126.24s]
# [Epoch 6/100] [D loss: 0.185666] [G loss: 0.398091] [Elapsed time: 146.79s]
# [Epoch 7/100] [D loss: 0.209392] [G loss: 0.399353] [Elapsed time: 168.26s]
# [Epoch 8/100] [D loss: 0.210711] [G loss: 0.554715] [Elapsed time: 188.40s]
# [Epoch 9/100] [D loss: 0.317636] [G loss: 0.719230] [Elapsed time: 208.76s]
# [Epoch 10/100] [D loss: 0.185272] [G loss: 0.289057] [Elapsed time: 229.45s]
# [Epoch 11/100] [D loss: 0.179008] [G loss: 0.318246] [Elapsed time: 249.99s]
# [Epoch 12/100] [D loss: 0.189688] [G loss: 0.378164] [Elapsed time: 270.39s]
# [Epoch 13/100] [D loss: 0.174400] [G loss: 0.500203] [Elapsed time: 290.78s]
# [Epoch 14/100] [D loss: 0.189056] [G loss: 0.430203] [Elapsed time: 311.31s]
# [Epoch 15/100] [D loss: 0.185069] [G loss: 0.312929] [Elapsed time: 331.58s]
# [Epoch 16/100] [D loss: 0.220831] [G loss: 0.257945] [Elapsed time: 353.29s]
# [Epoch 17/100] [D loss: 0.193763] [G loss: 0.404728] [Elapsed time: 373.65s]
# [Epoch 18/100] [D loss: 0.139570] [G loss: 0.388167] [Elapsed time: 394.05s]
# [Epoch 19/100] [D loss: 0.202990] [G loss: 0.401405] [Elapsed time: 414.59s]
# [Epoch 20/100] [D loss: 0.216817] [G loss: 0.188459] [Elapsed time: 435.24s]
# [Epoch 21/100] [D loss: 0.209835] [G loss: 0.374561] [Elapsed time: 455.81s]
# [Epoch 22/100] [D loss: 0.234100] [G loss: 0.391152] [Elapsed time: 476.33s]
# [Epoch 23/100] [D loss: 0.200686] [G loss: 0.403404] [Elapsed time: 496.57s]
# [Epoch 24/100] [D loss: 0.193928] [G loss: 0.446760] [Elapsed time: 516.84s]
# [Epoch 25/100] [D loss: 0.216277] [G loss: 0.373785] [Elapsed time: 538.40s]
# [Epoch 26/100] [D loss: 0.205950] [G loss: 0.373984] [Elapsed time: 558.82s]
# [Epoch 27/100] [D loss: 0.226266] [G loss: 0.382196] [Elapsed time: 579.15s]
# [Epoch 28/100] [D loss: 0.246595] [G loss: 0.341580] [Elapsed time: 599.80s]
# [Epoch 29/100] [D loss: 0.237616] [G loss: 0.414896] [Elapsed time: 620.03s]
# [Epoch 30/100] [D loss: 0.164630] [G loss: 0.275628] [Elapsed time: 640.35s]
# [Epoch 31/100] [D loss: 0.233728] [G loss: 0.306133] [Elapsed time: 661.00s]
# [Epoch 32/100] [D loss: 0.246565] [G loss: 0.426709] [Elapsed time: 681.23s]
# [Epoch 33/100] [D loss: 0.205372] [G loss: 0.398087] [Elapsed time: 701.65s]
# [Epoch 34/100] [D loss: 0.189489] [G loss: 0.326503] [Elapsed time: 723.27s]
# [Epoch 35/100] [D loss: 0.276649] [G loss: 0.491426] [Elapsed time: 743.28s]
# [Epoch 36/100] [D loss: 0.261879] [G loss: 0.280039] [Elapsed time: 763.52s]
# [Epoch 37/100] [D loss: 0.224243] [G loss: 0.427973] [Elapsed time: 783.94s]
# [Epoch 38/100] [D loss: 0.235116] [G loss: 0.324497] [Elapsed time: 804.76s]
# [Epoch 39/100] [D loss: 0.234515] [G loss: 0.291970] [Elapsed time: 825.21s]
# [Epoch 40/100] [D loss: 0.230132] [G loss: 0.320924] [Elapsed time: 845.70s]
# [Epoch 41/100] [D loss: 0.243137] [G loss: 0.339357] [Elapsed time: 865.75s]
# [Epoch 42/100] [D loss: 0.255717] [G loss: 0.274347] [Elapsed time: 886.06s]
# [Epoch 43/100] [D loss: 0.238800] [G loss: 0.277825] [Elapsed time: 907.62s]
# [Epoch 44/100] [D loss: 0.232068] [G loss: 0.263740] [Elapsed time: 927.96s]
# [Epoch 45/100] [D loss: 0.315928] [G loss: 0.300766] [Elapsed time: 948.20s]
# [Epoch 46/100] [D loss: 0.200909] [G loss: 0.337883] [Elapsed time: 968.39s]
# [Epoch 47/100] [D loss: 0.221820] [G loss: 0.374226] [Elapsed time: 988.56s]
# [Epoch 48/100] [D loss: 0.172227] [G loss: 0.316852] [Elapsed time: 1008.88s]
# [Epoch 49/100] [D loss: 0.270195] [G loss: 0.342462] [Elapsed time: 1029.27s]
# [Epoch 50/100] [D loss: 0.258456] [G loss: 0.259559] [Elapsed time: 1049.44s]
# [Epoch 51/100] [D loss: 0.225009] [G loss: 0.362116] [Elapsed time: 1069.79s]
# [Epoch 52/100] [D loss: 0.227981] [G loss: 0.319303] [Elapsed time: 1091.19s]
# [Epoch 53/100] [D loss: 0.202612] [G loss: 0.319378] [Elapsed time: 1111.37s]
# [Epoch 54/100] [D loss: 0.209750] [G loss: 0.355393] [Elapsed time: 1131.73s]
# [Epoch 55/100] [D loss: 0.162642] [G loss: 0.336963] [Elapsed time: 1151.98s]
# [Epoch 56/100] [D loss: 0.245915] [G loss: 0.272411] [Elapsed time: 1172.25s]
# [Epoch 57/100] [D loss: 0.229569] [G loss: 0.353926] [Elapsed time: 1192.62s]
# [Epoch 58/100] [D loss: 0.196082] [G loss: 0.305856] [Elapsed time: 1212.92s]
# [Epoch 59/100] [D loss: 0.222516] [G loss: 0.418392] [Elapsed time: 1233.15s]
# [Epoch 60/100] [D loss: 0.223162] [G loss: 0.412025] [Elapsed time: 1253.43s]
# [Epoch 61/100] [D loss: 0.162216] [G loss: 0.335804] [Elapsed time: 1274.47s]
# [Epoch 62/100] [D loss: 0.226802] [G loss: 0.287524] [Elapsed time: 1295.01s]
# [Epoch 63/100] [D loss: 0.243693] [G loss: 0.313096] [Elapsed time: 1315.20s]
# [Epoch 64/100] [D loss: 0.202387] [G loss: 0.283983] [Elapsed time: 1335.19s]
# [Epoch 65/100] [D loss: 0.218094] [G loss: 0.310497] [Elapsed time: 1355.30s]
# [Epoch 66/100] [D loss: 0.276894] [G loss: 0.322260] [Elapsed time: 1375.53s]
# [Epoch 67/100] [D loss: 0.253643] [G loss: 0.273060] [Elapsed time: 1395.68s]
# [Epoch 68/100] [D loss: 0.189215] [G loss: 0.304655] [Elapsed time: 1415.77s]
# [Epoch 69/100] [D loss: 0.232865] [G loss: 0.310937] [Elapsed time: 1435.98s]
# [Epoch 70/100] [D loss: 0.248091] [G loss: 0.356358] [Elapsed time: 1456.27s]
# [Epoch 71/100] [D loss: 0.252808] [G loss: 0.339710] [Elapsed time: 1477.43s]
# [Epoch 72/100] [D loss: 0.249029] [G loss: 0.286629] [Elapsed time: 1497.81s]
# [Epoch 73/100] [D loss: 0.216692] [G loss: 0.269621] [Elapsed time: 1518.03s]
# [Epoch 74/100] [D loss: 0.218189] [G loss: 0.302083] [Elapsed time: 1538.17s]
# [Epoch 75/100] [D loss: 0.259272] [G loss: 0.262552] [Elapsed time: 1558.48s]
# [Epoch 76/100] [D loss: 0.247199] [G loss: 0.345010] [Elapsed time: 1578.60s]
# [Epoch 77/100] [D loss: 0.229508] [G loss: 0.353955] [Elapsed time: 1598.77s]
# [Epoch 78/100] [D loss: 0.222580] [G loss: 0.300060] [Elapsed time: 1618.75s]
# [Epoch 79/100] [D loss: 0.248644] [G loss: 0.380185] [Elapsed time: 1638.76s]
# [Epoch 80/100] [D loss: 0.235828] [G loss: 0.278314] [Elapsed time: 1659.92s]
# [Epoch 81/100] [D loss: 0.242228] [G loss: 0.276574] [Elapsed time: 1680.21s]
# [Epoch 82/100] [D loss: 0.192497] [G loss: 0.307861] [Elapsed time: 1700.52s]
# [Epoch 83/100] [D loss: 0.196631] [G loss: 0.309779] [Elapsed time: 1720.49s]
# [Epoch 84/100] [D loss: 0.238265] [G loss: 0.313462] [Elapsed time: 1740.84s]
# [Epoch 85/100] [D loss: 0.240119] [G loss: 0.309927] [Elapsed time: 1761.03s]
# [Epoch 86/100] [D loss: 0.218607] [G loss: 0.296439] [Elapsed time: 1781.09s]
# [Epoch 87/100] [D loss: 0.212811] [G loss: 0.248063] [Elapsed time: 1801.18s]
# [Epoch 88/100] [D loss: 0.254911] [G loss: 0.295820] [Elapsed time: 1821.01s]
# [Epoch 89/100] [D loss: 0.286151] [G loss: 0.285806] [Elapsed time: 1842.18s]
# [Epoch 90/100] [D loss: 0.241924] [G loss: 0.244832] [Elapsed time: 1862.33s]
# [Epoch 91/100] [D loss: 0.239491] [G loss: 0.271828] [Elapsed time: 1882.28s]
# [Epoch 92/100] [D loss: 0.248932] [G loss: 0.308397] [Elapsed time: 1902.25s]
# [Epoch 93/100] [D loss: 0.249790] [G loss: 0.267278] [Elapsed time: 1922.48s]
# [Epoch 94/100] [D loss: 0.254160] [G loss: 0.278584] [Elapsed time: 1942.45s]
# [Epoch 95/100] [D loss: 0.266073] [G loss: 0.232302] [Elapsed time: 1962.37s]
# [Epoch 96/100] [D loss: 0.240139] [G loss: 0.270706] [Elapsed time: 1982.30s]
# [Epoch 97/100] [D loss: 0.219591] [G loss: 0.260725] [Elapsed time: 2002.36s]
# [Epoch 98/100] [D loss: 0.240087] [G loss: 0.299771] [Elapsed time: 2022.61s]
# [Epoch 99/100] [D loss: 0.266840] [G loss: 0.273878] [Elapsed time: 2043.24s]

# %% [markdown]
# * 생성된 이미지 예시를 출력합니다.

# %%
from IPython.display import Image as Display

Display('./results/simple/28000.png')

# %% [markdown]
# * 다음의 코드를 이용하여 학습된 모델 파라미터를 저장할 수 있습니다.

# %%
# 모델 파라미터 저장
torch.save(simple_generator.state_dict(), "Simple_Generator_for_Face_Mask.pt")
torch.save(simple_discriminator.state_dict(), "Simple_Discriminator_for_Face_Mask.pt")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# * 학습된 모델 파라미터를 불러와 이미지 생성을 진행할 수 있습니다.

# %%
# 생성자(generator) 초기화
simple_generator = SimpleGenerator()
simple_generator.cuda()
simple_generator.load_state_dict(torch.load("Simple_Generator_for_Face_Mask.pt"))
simple_generator.eval()
# Out:
# SimpleGenerator(
#   (label_embed): Embedding(2, 2)
#   (model): Sequential(
#     (0): Linear(in_features=102, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=2048, bias=True)
#     (12): BatchNorm1d(2048, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2, inplace=True)
#     (14): Linear(in_features=2048, out_features=4096, bias=True)
#     (15): Tanh()
#   )
# )

# %% [markdown]
# * 마스크를 착용한 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(0)

# 이미지 생성
generated_imgs = simple_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/simple/with_mask.png', nrow=10, normalize=True)

Display('./results/simple/with_mask.png')

# %% [markdown]
# * 마스크를 착용하지 않은 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(1)

# 이미지 생성
generated_imgs = simple_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/simple/with_no_mask.png', nrow=10, normalize=True)

Display('./results/simple/with_no_mask.png')

# %% [markdown]
# #### <b>(알아보기) DCGAN 실습 - 모델 정의</b>
#
# * 논문 제목: [Deep Convolutional Generative Adversarial Networks](https://arxiv.org/abs/1511.06434) <b>(ICLR 2016)</b>
# * Convoluational Layer를 활용하여 이미지 생성에 높은 성능을 보이는 DCGAN 모델을 학습해 봅시다.
#     * 마스크 착용 여부를 선택하기 위해 <b>조건부(conditional) GAN</b>을 이용합니다.
#     * <b>Reference</b>: [Conditional Generative Adversarial Nets (2014)](https://arxiv.org/abs/1411.1784)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 생성자(Generator) 및 판별자(Discriminator) 모델을 정의합니다.
#     * 생성자 클래스: DCGANGenerator
#     * 판별자 클래스: DCGANDiscriminator
# * 본 소스코드는 원본 논문에서 제안한 아키텍처와 유사한 아키텍처를 이용합니다.
# * <b>Reference</b>: [PyTorch DCGAN 예시 코드](https://github.com/eriklindernoren/PyTorch-GAN/blob/master/implementations/dcgan/dcgan.py)

# %%
latent_dim = 100
n_classes = 2


# 생성자(Generator) 클래스 정의
class DCGANGenerator(nn.Module):
    def __init__(self):
        super(DCGANGenerator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        self.init_size = 4 # 원본 크기보다 16배 작은 값으로 초기화
        self.layer1 = nn.Sequential(nn.Linear(latent_dim + n_classes, 512 * self.init_size * self.init_size)) # 초기 채널의 크기는 512 

        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(512), # 채널의 크기와 동일
            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지
            nn.BatchNorm2d(512, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(512, 256, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 256으로
            nn.BatchNorm2d(256, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(256, 128, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 128로
            nn.BatchNorm2d(128, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 64로
            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 1, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 3으로
            nn.Tanh(),
        )

    def forward(self, noise, labels):
        # 노이즈(noise) 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((noise, self.label_embed(labels)), -1)
        output = self.layer1(inputs)
        output = output.view(output.size(0), 512, self.init_size, self.init_size)
        output = self.conv_blocks(output)
        return output


# 판별자(Discriminator) 클래스 정의
class DCGANDiscriminator(nn.Module):
    def __init__(self):
        super(DCGANDiscriminator, self).__init__()

        def make_block(in_channels, out_channels, bn=True):
            # 하나의 블록(block)을 반복할 때마다 너비와 높이는 2배씩 감소
            block = [nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)]
            block.append(nn.LeakyReLU(0.2, inplace=True))
            block.append(nn.Dropout2d(0.25))
            if bn:
                block.append(nn.BatchNorm2d(out_channels, 0.8))
            return block

        # 너비와 높이가 32배씩 감소
        self.conv_blocks = nn.Sequential(
            *make_block(2, 32, bn=False),
            *make_block(32, 64),
            *make_block(64, 128),
            *make_block(128, 256),
            *make_block(256, 512),
        )

        self.classifier = nn.Sequential(
            nn.Linear(512 * 2 * 2, 1),
            nn.Sigmoid()
        )

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, 1 * 64 * 64)

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        # 이미지 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        embed = self.label_embed(labels).view((img.size(0), 1, 64, 64))
        inputs = torch.cat((img, embed), 1)
        output = self.conv_blocks(inputs)
        output = output.view(output.size(0), -1)
        output = self.classifier(output)
        return output

# %% [markdown]
# #### <b>(알아보기) DCGAN 실습 - 모델 학습 및 샘플링</b>
#
# * 학습을 위해 생성자와 판별자 모델을 초기화합니다.
# * 적절한 하이퍼 파라미터를 설정합니다.

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)


# 생성자(generator)와 판별자(discriminator) 초기화
dcgan_generator = DCGANGenerator()
dcgan_discriminator = DCGANDiscriminator()

dcgan_generator.cuda()
dcgan_discriminator.cuda()

# 가중치(weights) 초기화
dcgan_generator.apply(weights_init_normal)
dcgan_discriminator.apply(weights_init_normal)

# 손실 함수(loss function)
adversarial_loss = nn.MSELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0001

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(dcgan_generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(dcgan_discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# * 모델을 학습하면서 주기적으로 샘플링하여 결과를 확인할 수 있습니다.

# %%
# !mkdir -p ./results/dcgan/

n_epochs = 100 # 학습의 횟수(epoch) 설정
sample_interval = 500 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(train_dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()
        labels = labels.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()
        generated_labels = torch.randint(0, n_classes, (imgs.shape[0],)).cuda()

        # 이미지 생성
        generated_imgs = dcgan_generator(z, generated_labels)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(dcgan_discriminator(generated_imgs, generated_labels), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(dcgan_discriminator(real_imgs, labels), real)
        fake_loss = adversarial_loss(dcgan_discriminator(generated_imgs.detach(), generated_labels), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(train_dataloader) + i
        if done % sample_interval == 0:
            # 클래스당 8개의 이미지를 생성하여 2 X 8 격자 이미지에 출력
            z = torch.normal(mean=0, std=1, size=(n_classes * 8, latent_dim)).cuda()
            labels = torch.LongTensor([i for i in range(n_classes) for _ in range(8)]).cuda()
            generated_imgs = dcgan_generator(z, labels)
            save_image(generated_imgs, f"./results/dcgan/{done}.png", nrow=8, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/100] [D loss: 0.254665] [G loss: 0.224937] [Elapsed time: 27.73s]
# [Epoch 1/100] [D loss: 0.252884] [G loss: 0.245564] [Elapsed time: 52.03s]
# [Epoch 2/100] [D loss: 0.256928] [G loss: 0.239177] [Elapsed time: 76.81s]
# [Epoch 3/100] [D loss: 0.252391] [G loss: 0.252930] [Elapsed time: 101.33s]
# [Epoch 4/100] [D loss: 0.251684] [G loss: 0.252497] [Elapsed time: 125.42s]
# [Epoch 5/100] [D loss: 0.248933] [G loss: 0.251855] [Elapsed time: 149.48s]
# [Epoch 6/100] [D loss: 0.248496] [G loss: 0.243956] [Elapsed time: 173.79s]
# [Epoch 7/100] [D loss: 0.250639] [G loss: 0.248277] [Elapsed time: 199.43s]
# [Epoch 8/100] [D loss: 0.248141] [G loss: 0.254558] [Elapsed time: 224.12s]
# [Epoch 9/100] [D loss: 0.249750] [G loss: 0.248131] [Elapsed time: 248.80s]
# [Epoch 10/100] [D loss: 0.248948] [G loss: 0.248812] [Elapsed time: 273.34s]
# [Epoch 11/100] [D loss: 0.250873] [G loss: 0.253524] [Elapsed time: 298.09s]
# [Epoch 12/100] [D loss: 0.249836] [G loss: 0.247694] [Elapsed time: 322.74s]
# [Epoch 13/100] [D loss: 0.248233] [G loss: 0.253120] [Elapsed time: 347.40s]
# [Epoch 14/100] [D loss: 0.248560] [G loss: 0.248662] [Elapsed time: 372.25s]
# [Epoch 15/100] [D loss: 0.251050] [G loss: 0.247710] [Elapsed time: 397.85s]
# [Epoch 16/100] [D loss: 0.249290] [G loss: 0.252196] [Elapsed time: 422.44s]
# [Epoch 17/100] [D loss: 0.250651] [G loss: 0.256108] [Elapsed time: 447.16s]
# [Epoch 18/100] [D loss: 0.249879] [G loss: 0.255850] [Elapsed time: 471.78s]
# [Epoch 19/100] [D loss: 0.250642] [G loss: 0.246275] [Elapsed time: 496.60s]
# [Epoch 20/100] [D loss: 0.248762] [G loss: 0.263330] [Elapsed time: 521.28s]
# [Epoch 21/100] [D loss: 0.258489] [G loss: 0.235594] [Elapsed time: 546.08s]
# [Epoch 22/100] [D loss: 0.238916] [G loss: 0.237067] [Elapsed time: 571.69s]
# [Epoch 23/100] [D loss: 0.252826] [G loss: 0.262551] [Elapsed time: 596.67s]
# [Epoch 24/100] [D loss: 0.243197] [G loss: 0.265371] [Elapsed time: 621.47s]
# [Epoch 25/100] [D loss: 0.257633] [G loss: 0.266258] [Elapsed time: 646.21s]
# [Epoch 26/100] [D loss: 0.247592] [G loss: 0.255494] [Elapsed time: 671.01s]
# [Epoch 27/100] [D loss: 0.247404] [G loss: 0.273979] [Elapsed time: 695.78s]
# [Epoch 28/100] [D loss: 0.242361] [G loss: 0.237580] [Elapsed time: 720.50s]
# [Epoch 29/100] [D loss: 0.244048] [G loss: 0.257387] [Elapsed time: 745.33s]
# [Epoch 30/100] [D loss: 0.251082] [G loss: 0.245071] [Elapsed time: 770.88s]
# [Epoch 31/100] [D loss: 0.251216] [G loss: 0.265294] [Elapsed time: 795.68s]
# [Epoch 32/100] [D loss: 0.251346] [G loss: 0.270369] [Elapsed time: 820.36s]
# [Epoch 33/100] [D loss: 0.255908] [G loss: 0.248481] [Elapsed time: 845.13s]
# [Epoch 34/100] [D loss: 0.243684] [G loss: 0.263317] [Elapsed time: 869.72s]
# [Epoch 35/100] [D loss: 0.249419] [G loss: 0.255181] [Elapsed time: 894.51s]
# [Epoch 36/100] [D loss: 0.252307] [G loss: 0.260075] [Elapsed time: 919.16s]
# [Epoch 37/100] [D loss: 0.241956] [G loss: 0.284424] [Elapsed time: 944.76s]
# [Epoch 38/100] [D loss: 0.244352] [G loss: 0.251398] [Elapsed time: 969.49s]
# [Epoch 39/100] [D loss: 0.220480] [G loss: 0.263385] [Elapsed time: 994.25s]
# [Epoch 40/100] [D loss: 0.246992] [G loss: 0.262851] [Elapsed time: 1018.98s]
# [Epoch 41/100] [D loss: 0.260554] [G loss: 0.257160] [Elapsed time: 1043.76s]
# [Epoch 42/100] [D loss: 0.248451] [G loss: 0.239343] [Elapsed time: 1068.48s]
# [Epoch 43/100] [D loss: 0.251734] [G loss: 0.267889] [Elapsed time: 1093.14s]
# [Epoch 44/100] [D loss: 0.247946] [G loss: 0.229751] [Elapsed time: 1117.83s]
# [Epoch 45/100] [D loss: 0.232268] [G loss: 0.242426] [Elapsed time: 1143.43s]
# [Epoch 46/100] [D loss: 0.272678] [G loss: 0.200223] [Elapsed time: 1168.10s]
# [Epoch 47/100] [D loss: 0.256332] [G loss: 0.300561] [Elapsed time: 1192.92s]
# [Epoch 48/100] [D loss: 0.243602] [G loss: 0.266634] [Elapsed time: 1217.58s]
# [Epoch 49/100] [D loss: 0.242585] [G loss: 0.293864] [Elapsed time: 1242.31s]
# [Epoch 50/100] [D loss: 0.254932] [G loss: 0.264454] [Elapsed time: 1267.12s]
# [Epoch 51/100] [D loss: 0.244591] [G loss: 0.250033] [Elapsed time: 1291.84s]
# [Epoch 52/100] [D loss: 0.256477] [G loss: 0.240181] [Elapsed time: 1317.37s]
# [Epoch 53/100] [D loss: 0.233642] [G loss: 0.283724] [Elapsed time: 1342.08s]
# [Epoch 54/100] [D loss: 0.219343] [G loss: 0.287455] [Elapsed time: 1366.84s]
# [Epoch 55/100] [D loss: 0.243364] [G loss: 0.229898] [Elapsed time: 1391.63s]
# [Epoch 56/100] [D loss: 0.244287] [G loss: 0.259526] [Elapsed time: 1416.41s]
# [Epoch 57/100] [D loss: 0.243935] [G loss: 0.239347] [Elapsed time: 1441.16s]
# [Epoch 58/100] [D loss: 0.246754] [G loss: 0.240035] [Elapsed time: 1465.86s]
# [Epoch 59/100] [D loss: 0.246380] [G loss: 0.247730] [Elapsed time: 1490.57s]
# [Epoch 60/100] [D loss: 0.254957] [G loss: 0.246440] [Elapsed time: 1516.27s]
# [Epoch 61/100] [D loss: 0.236641] [G loss: 0.277884] [Elapsed time: 1540.95s]
# [Epoch 62/100] [D loss: 0.241589] [G loss: 0.255351] [Elapsed time: 1565.63s]
# [Epoch 63/100] [D loss: 0.245954] [G loss: 0.243567] [Elapsed time: 1590.30s]
# [Epoch 64/100] [D loss: 0.250116] [G loss: 0.249629] [Elapsed time: 1614.97s]
# [Epoch 65/100] [D loss: 0.241235] [G loss: 0.259978] [Elapsed time: 1639.59s]
# [Epoch 66/100] [D loss: 0.227766] [G loss: 0.287120] [Elapsed time: 1664.22s]
# [Epoch 67/100] [D loss: 0.238802] [G loss: 0.249576] [Elapsed time: 1689.93s]
# [Epoch 68/100] [D loss: 0.236795] [G loss: 0.258730] [Elapsed time: 1714.59s]
# [Epoch 69/100] [D loss: 0.240554] [G loss: 0.272685] [Elapsed time: 1739.33s]
# [Epoch 70/100] [D loss: 0.245724] [G loss: 0.243599] [Elapsed time: 1764.07s]
# [Epoch 71/100] [D loss: 0.234529] [G loss: 0.280206] [Elapsed time: 1788.82s]
# [Epoch 72/100] [D loss: 0.283000] [G loss: 0.225873] [Elapsed time: 1813.51s]
# [Epoch 73/100] [D loss: 0.236042] [G loss: 0.262062] [Elapsed time: 1838.15s]
# [Epoch 74/100] [D loss: 0.240921] [G loss: 0.265964] [Elapsed time: 1862.81s]
# [Epoch 75/100] [D loss: 0.224541] [G loss: 0.255860] [Elapsed time: 1888.20s]
# [Epoch 76/100] [D loss: 0.215614] [G loss: 0.258650] [Elapsed time: 1912.91s]
# [Epoch 77/100] [D loss: 0.240391] [G loss: 0.254502] [Elapsed time: 1937.47s]
# [Epoch 78/100] [D loss: 0.240505] [G loss: 0.258795] [Elapsed time: 1962.20s]
# [Epoch 79/100] [D loss: 0.245332] [G loss: 0.207570] [Elapsed time: 1986.89s]
# [Epoch 80/100] [D loss: 0.249944] [G loss: 0.262742] [Elapsed time: 2011.43s]
# [Epoch 81/100] [D loss: 0.259534] [G loss: 0.241212] [Elapsed time: 2036.06s]
# [Epoch 82/100] [D loss: 0.253194] [G loss: 0.254342] [Elapsed time: 2061.69s]
# [Epoch 83/100] [D loss: 0.239361] [G loss: 0.260337] [Elapsed time: 2086.43s]
# [Epoch 84/100] [D loss: 0.279156] [G loss: 0.214708] [Elapsed time: 2111.08s]
# [Epoch 85/100] [D loss: 0.246158] [G loss: 0.262710] [Elapsed time: 2135.73s]
# [Epoch 86/100] [D loss: 0.248620] [G loss: 0.290827] [Elapsed time: 2160.38s]
# [Epoch 87/100] [D loss: 0.269721] [G loss: 0.263680] [Elapsed time: 2184.99s]
# [Epoch 88/100] [D loss: 0.237372] [G loss: 0.267083] [Elapsed time: 2209.66s]
# [Epoch 89/100] [D loss: 0.230911] [G loss: 0.250457] [Elapsed time: 2234.32s]
# [Epoch 90/100] [D loss: 0.252766] [G loss: 0.147728] [Elapsed time: 2259.85s]
# [Epoch 91/100] [D loss: 0.215946] [G loss: 0.328565] [Elapsed time: 2284.51s]
# [Epoch 92/100] [D loss: 0.257766] [G loss: 0.260234] [Elapsed time: 2309.22s]
# [Epoch 93/100] [D loss: 0.260244] [G loss: 0.265268] [Elapsed time: 2334.02s]
# [Epoch 94/100] [D loss: 0.233021] [G loss: 0.238105] [Elapsed time: 2358.83s]
# [Epoch 95/100] [D loss: 0.223631] [G loss: 0.210617] [Elapsed time: 2383.63s]
# [Epoch 96/100] [D loss: 0.244430] [G loss: 0.245370] [Elapsed time: 2408.31s]
# [Epoch 97/100] [D loss: 0.285303] [G loss: 0.285079] [Elapsed time: 2433.89s]
# [Epoch 98/100] [D loss: 0.223316] [G loss: 0.294983] [Elapsed time: 2458.72s]
# [Epoch 99/100] [D loss: 0.248926] [G loss: 0.194821] [Elapsed time: 2483.41s]

# %% [markdown]
# * 생성된 이미지 예시를 출력합니다.

# %%
from IPython.display import Image as Display

Display('./results/dcgan/28000.png')

# %% [markdown]
# * 다음의 코드를 이용하여 학습된 모델 파라미터를 저장할 수 있습니다.

# %%
# 모델 파라미터 저장
torch.save(dcgan_generator.state_dict(), "DCGAN_Generator_for_Face_Mask.pt")
torch.save(dcgan_discriminator.state_dict(), "DCGAN_Discriminator_for_Face_Mask.pt")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# * 학습된 모델 파라미터를 불러와 이미지 생성을 진행할 수 있습니다.

# %%
# 생성자(generator) 초기화
dcgan_generator = DCGANGenerator()
dcgan_generator.cuda()
dcgan_generator.load_state_dict(torch.load("DCGAN_Generator_for_Face_Mask.pt"))
dcgan_generator.eval()
# Out:
# DCGANGenerator(
#   (label_embed): Embedding(2, 2)
#   (layer1): Sequential(
#     (0): Linear(in_features=102, out_features=8192, bias=True)
#   )
#   (conv_blocks): Sequential(
#     (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Upsample(scale_factor=2.0, mode=nearest)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): BatchNorm2d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Upsample(scale_factor=2.0, mode=nearest)
#     (6): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Upsample(scale_factor=2.0, mode=nearest)
#     (10): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.2, inplace=True)
#     (13): Upsample(scale_factor=2.0, mode=nearest)
#     (14): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(64, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.2, inplace=True)
#     (17): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): Tanh()
#   )
# )

# %% [markdown]
# * 마스크를 착용한 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(0)

# 이미지 생성
generated_imgs = dcgan_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/dcgan/with_mask.png', nrow=10, normalize=True)

Display('./results/dcgan/with_mask.png')

# %% [markdown]
# * 마스크를 착용하지 않은 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(1)

# 이미지 생성
generated_imgs = dcgan_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/dcgan/with_no_mask.png', nrow=10, normalize=True)

Display('./results/dcgan/with_no_mask.png')

# %% [markdown]
# #### <b>(알아보기) GAN 모델 평가하기 - FID Score</b>
#
# * 논문 제목: [Rethinking the Inception Architecture for Computer Vision](https://arxiv.org/abs/1512.00567) <b>(CVPR 2016)</b>
# * Fréchet Inception Distance(FID) 계산 방법
#     * <b>생성된 이미지</b>들과 <b>실제 이미지</b>들을 ImageNet에 넣어 특징(feature)을 추출합니다.
#     * 생성된 이미지 특징 분포 G와 실제 이미지 특징 분포 X를 가우시안 분포라고 가정합니다.
#     * 두 분포가 얼마나 다른지 계산하기 위해 FID(X, G)를 계산합니다.
# * [FID score for PyTorch](https://github.com/hukkelas/pytorch-frechet-inception-distance) 라이브러리를 이용해 간단히 계산할 수 있습니다.
#     * 다음과 같이 소스코드를 다운로드할 수 있습니다.

# %%
# !git clone https://github.com/hukkelas/pytorch-frechet-inception-distance
# Out:
# Cloning into 'pytorch-frechet-inception-distance'...
# remote: Enumerating objects: 22, done.
# remote: Total 22 (delta 0), reused 0 (delta 0), pack-reused 22
# Unpacking objects: 100% (22/22), done.

# %% [markdown]
# * <b>Simple GAN</b>: FID 점수를 계산하기 위해 마스크 착용 및 마스크 미착용 이미지를 1,000장씩 생성합니다.

# %%
# !mkdir -p ./results/simple/with_mask
# !mkdir -p ./results/simple/without_mask

from IPython.display import Image as Display


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(0)
    # 이미지 생성
    generated_imgs = simple_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/with_mask/{i * 100 + j}.png', normalize=True)


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(1)
    # 이미지 생성
    generated_imgs = simple_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/without_mask/{i * 100 + j}.png', normalize=True)

# %% [markdown]
# * <b>DCGAN</b>: FID 점수를 계산하기 위해 마스크 착용 및 마스크 미착용 이미지를 1,000장씩 생성합니다.

# %%
# !mkdir -p ./results/dcgan/with_mask
# !mkdir -p ./results/dcgan/without_mask

from IPython.display import Image as Display


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(0)
    # 이미지 생성
    generated_imgs = dcgan_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/dcgan/with_mask/{i * 100 + j}.png', normalize=True)


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(1)
    # 이미지 생성
    generated_imgs = dcgan_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/dcgan/without_mask/{i * 100 + j}.png', normalize=True)

# %% [markdown]
# * 다음과 같이 <b>FID를 계산</b>할 수 있습니다.
#     * <b>FID 값이 낮을수록 우수한 모델</b>입니다.
# * 메모리 초과 오류(CUDA error: out of memory)가 발생할 수 있습니다.
#     * 메모리 초과가 발생할 때는 학습했던 GAN 네트워크를 잘 저장한 뒤에 <b>[런타임]</b> - <b>[런타임 다시 시작]</b>을 진행합니다.
# * Simple GAN의 마스크 미착용 FID 점수: 247.69
# * Simple GAN의 마스크 착용 FID 점수: 320.88
# * DCGAN의 마스크 미착용 FID 점수: 171.67
# * DCGAN의 마스크 착용 FID 점수: 114.97

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# Out:
# Looking for images in ./results/simple/without_mask/*.png
# Looking for images in ./results/simple/without_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.jpg
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100% 104M/104M [00:02<00:00, 47.3MB/s]
# 249.73780451196257

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32
# Out:
# Looking for images in ./results/simple/with_mask/*.png
# Looking for images in ./results/simple/with_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.jpg
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 326.0790094134982

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/dcgan/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# Out:
# Looking for images in ./results/dcgan/without_mask/*.png
# Looking for images in ./results/dcgan/without_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.jpg
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 158.21035869677644

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/dcgan/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32
# Out:
# Looking for images in ./results/dcgan/with_mask/*.png
# Looking for images in ./results/dcgan/with_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.jpg
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 104.1443743371278

# %% [markdown]
# #### <b>Problem 1. 나만의 모델을 만들어 학습 및 평가하기</b>
#
# * 나만의 GAN 모델을 이용해 <b>최대한 높은 FID 점수</b>를 받아보세요.
#     * (Hint) 200 epochs 이상으로 학습해보기
#     * (Hint) DCGAN의 아키텍처를 효율적으로 바꿔보기
#     * (Hint) WGAN 등 [다른 아키텍처들을](https://github.com/eriklindernoren/PyTorch-GAN) 적용해보기
#     * (Hint) 사전 학습된(pre-trained) GAN 모델 사용해보기
# * 결과적으로 자신이 학습한 모델의 <b>최종 FID 점수(score)를 작성</b>하세요.
#     * 마스크 착용 및 미착용 이미지를 <b>각각 1,000장씩 생성</b>하여 FID를 계산합니다.
#     * 마스크 착용: {답을 쓰세요.}
#     * 마스크 미착용: {답을 쓰세요.}
# * 결과 이미지의 해상도는 1 X 64 X 64가 되어야 합니다.

# %%
# !pip install utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import utils
from PIL import Image

import torch
import torch.nn as nn
import torch.autograd as autograd

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %%
transforms_train = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.Grayscale(1),
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)) # normalization
])

data_dir = './Face-Mask-Classification-20000-Dataset/'
train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
print('Train dataset size:', len(train_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Train dataset size: 18000
# Class names: ['with_mask', 'without_mask']

# %%
# 생성자(Generator) 클래스 정의
class CustomGenerator(nn.Module):
    def __init__(self):
        super(CustomGenerator, self).__init__()
        # 적절한 소스코드를 작성하세요.
        pass

    def forward(self, noise, labels):
        # 적절한 소스코드를 작성하세요.
        pass


# 판별자(Discriminator) 클래스 정의
class CustomDiscriminator(nn.Module):
    def __init__(self):
        super(CustomDiscriminator, self).__init__()
        # 적절한 소스코드를 작성하세요.
        pass

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        # 적절한 소스코드를 작성하세요.
        pass

# %%
class infoGenerator(nn.Module):
    # Network Architecture is exactly same as in infoGAN (https://arxiv.org/abs/1606.03657)
    # Architecture : FC1024_BR-FC7x7x128_BR-(64)4dc2s_BR-(1)4dc2s_S
    def __init__(self, input_dim=100, output_dim=1, input_size=64, class_num=2):
        super(infoGenerator, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.input_size = input_size
        self.class_num = class_num
        
        self.label_embed = nn.Embedding(self.class_num, self.class_num)

        self.fc = nn.Sequential(
            nn.Linear(self.input_dim + self.class_num, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Linear(1024, 128 * (self.input_size // 4) * (self.input_size // 4)),
            nn.BatchNorm1d(128 * (self.input_size // 4) * (self.input_size // 4)),
            nn.ReLU(),
        )
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(128, 64, 4, 2, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, self.output_dim, 4, 2, 1),
            nn.Tanh(),
        )
        #utils.initialize_weights(self)

    def forward(self, noise, labels):
        x = torch.cat((noise, self.label_embed(labels)), -1)
        x = self.fc(x)
        x = x.view(-1, 128, (self.input_size // 4), (self.input_size // 4))
        x = self.deconv(x)

        return x

class infoDiscriminator(nn.Module):
    # Network Architecture is exactly same as in infoGAN (https://arxiv.org/abs/1606.03657)
    # Architecture : (64)4c2s-(128)4c2s_BL-FC1024_BL-FC1_S
    def __init__(self, input_dim=100, output_dim=1, input_size=64, class_num=2):
        super(infoDiscriminator, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.input_size = input_size
        self.class_num = class_num
        
        self.label_embed = nn.Embedding(self.class_num, 1 * 64 * 64)

        def make_block(in_channels, out_channels, bn=True):
            # 하나의 블록(block)을 반복할 때마다 너비와 높이는 2배씩 감소
            block = [nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)]
            block.append(nn.LeakyReLU(0.2, inplace=True))
            block.append(nn.Dropout2d(0.25))
            if bn:
                block.append(nn.BatchNorm2d(out_channels, 0.8))
            return block

        # 너비와 높이가 32배씩 감소
        self.conv_blocks = nn.Sequential(
            *make_block(2, 32, bn=False),
            *make_block(32, 64),
            *make_block(64, 128),
            *make_block(128, 256),
            *make_block(256, 512),
        )
        
        self.conv = nn.Sequential(
            nn.Conv2d(self.input_dim + self.class_num, 64, 4, 2, 1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, 4, 2, 1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
        )
        self.fc = nn.Sequential(
            #nn.Linear(128 * (self.input_size // 4) * (self.input_size // 4), 1024),
            nn.Linear(512 * 2 * 2, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, self.output_dim),
            nn.Sigmoid(),
        )
        #utils.initialize_weights(self)

    def forward(self, img, labels):
        embed = self.label_embed(labels).view((img.size(0), 1, 64, 64))
        x = torch.cat((img, embed), 1)
        x = self.conv_blocks(x)
        x = x.view(x.size(0), -1)
        # x = x.view(-1, 128 * (self.input_size // 4) * (self.input_size // 4))
        x = self.fc(x)

        return x

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)


# 생성자(generator)와 판별자(discriminator) 초기화
infogan_generator = infoGenerator()
infogan_discriminator = infoDiscriminator()

infogan_generator.cuda()
infogan_discriminator.cuda()

# 가중치(weights) 초기화
infogan_generator.apply(weights_init_normal)
infogan_discriminator.apply(weights_init_normal)

# 손실 함수(loss function)
adversarial_loss = nn.MSELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0001

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(infogan_generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(infogan_discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
# !mkdir -p ./results/infogan/

# %%
# 모델 학습하는 코드 작성하기
# pass
# !mkdir -p ./results/infogan/

n_epochs = 200 # 학습의 횟수(epoch) 설정
latent_dim = 100
n_classes = 2
sample_interval = 500 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(train_dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()
        labels = labels.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()
        generated_labels = torch.randint(0, n_classes, (imgs.shape[0],)).cuda()

        # 이미지 생성
        generated_imgs = infogan_generator(z, generated_labels)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(infogan_discriminator(generated_imgs, generated_labels), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(infogan_discriminator(real_imgs, labels), real)
        fake_loss = adversarial_loss(infogan_discriminator(generated_imgs.detach(), generated_labels), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(train_dataloader) + i
        if done % sample_interval == 0:
            # 클래스당 8개의 이미지를 생성하여 2 X 8 격자 이미지에 출력
            z = torch.normal(mean=0, std=1, size=(n_classes * 8, latent_dim)).cuda()
            labels = torch.LongTensor([i for i in range(n_classes) for _ in range(8)]).cuda()
            generated_imgs = infogan_generator(z, labels)
            save_image(generated_imgs, f"./results/infogan/{done}.png", nrow=8, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/200] [D loss: 0.246561] [G loss: 0.260990] [Elapsed time: 25.92s]
# [Epoch 1/200] [D loss: 0.242347] [G loss: 0.327818] [Elapsed time: 47.87s]
# [Epoch 2/200] [D loss: 0.234306] [G loss: 0.271016] [Elapsed time: 71.22s]
# [Epoch 3/200] [D loss: 0.229779] [G loss: 0.245858] [Elapsed time: 93.92s]
# [Epoch 4/200] [D loss: 0.234489] [G loss: 0.277856] [Elapsed time: 116.26s]
# [Epoch 5/200] [D loss: 0.232180] [G loss: 0.288203] [Elapsed time: 139.17s]
# [Epoch 6/200] [D loss: 0.241099] [G loss: 0.261185] [Elapsed time: 161.09s]
# [Epoch 7/200] [D loss: 0.225249] [G loss: 0.295624] [Elapsed time: 182.85s]
# [Epoch 8/200] [D loss: 0.254053] [G loss: 0.282169] [Elapsed time: 204.67s]
# [Epoch 9/200] [D loss: 0.232583] [G loss: 0.330881] [Elapsed time: 226.97s]
# [Epoch 10/200] [D loss: 0.235296] [G loss: 0.365579] [Elapsed time: 248.92s]
# [Epoch 11/200] [D loss: 0.183458] [G loss: 0.380851] [Elapsed time: 271.10s]
# [Epoch 12/200] [D loss: 0.220469] [G loss: 0.322334] [Elapsed time: 293.76s]
# [Epoch 13/200] [D loss: 0.200331] [G loss: 0.392347] [Elapsed time: 315.80s]
# [Epoch 14/200] [D loss: 0.247587] [G loss: 0.391973] [Elapsed time: 337.54s]
# [Epoch 15/200] [D loss: 0.166371] [G loss: 0.468255] [Elapsed time: 359.40s]
# [Epoch 16/200] [D loss: 0.120640] [G loss: 0.562794] [Elapsed time: 381.22s]
# [Epoch 17/200] [D loss: 0.133021] [G loss: 0.475487] [Elapsed time: 403.16s]
# [Epoch 18/200] [D loss: 0.111392] [G loss: 0.683479] [Elapsed time: 424.81s]
# [Epoch 19/200] [D loss: 0.172177] [G loss: 0.562025] [Elapsed time: 446.57s]
# [Epoch 20/200] [D loss: 0.138716] [G loss: 0.449972] [Elapsed time: 469.70s]
# [Epoch 21/200] [D loss: 0.140739] [G loss: 0.523200] [Elapsed time: 491.40s]
# [Epoch 22/200] [D loss: 0.203321] [G loss: 0.694739] [Elapsed time: 513.27s]
# [Epoch 23/200] [D loss: 0.105464] [G loss: 0.604888] [Elapsed time: 535.15s]
# [Epoch 24/200] [D loss: 0.063474] [G loss: 0.439056] [Elapsed time: 556.85s]
# [Epoch 25/200] [D loss: 0.107964] [G loss: 0.728090] [Elapsed time: 578.75s]
# [Epoch 26/200] [D loss: 0.096500] [G loss: 0.687099] [Elapsed time: 600.58s]
# [Epoch 27/200] [D loss: 0.124058] [G loss: 0.783082] [Elapsed time: 622.14s]
# [Epoch 28/200] [D loss: 0.243374] [G loss: 0.800265] [Elapsed time: 645.11s]
# [Epoch 29/200] [D loss: 0.090671] [G loss: 0.384975] [Elapsed time: 666.91s]
# [Epoch 30/200] [D loss: 0.097437] [G loss: 0.642634] [Elapsed time: 688.51s]
# [Epoch 31/200] [D loss: 0.042512] [G loss: 0.535628] [Elapsed time: 710.58s]
# [Epoch 32/200] [D loss: 0.103129] [G loss: 0.294017] [Elapsed time: 732.32s]
# [Epoch 33/200] [D loss: 0.072158] [G loss: 0.842785] [Elapsed time: 754.14s]
# [Epoch 34/200] [D loss: 0.062209] [G loss: 0.728836] [Elapsed time: 776.02s]
# [Epoch 35/200] [D loss: 0.336790] [G loss: 0.470369] [Elapsed time: 797.82s]
# [Epoch 36/200] [D loss: 0.071009] [G loss: 0.711993] [Elapsed time: 820.73s]
# [Epoch 37/200] [D loss: 0.112351] [G loss: 0.831895] [Elapsed time: 842.79s]
# [Epoch 38/200] [D loss: 0.045965] [G loss: 0.654535] [Elapsed time: 864.52s]
# [Epoch 39/200] [D loss: 0.040631] [G loss: 0.815266] [Elapsed time: 886.52s]
# [Epoch 40/200] [D loss: 0.142660] [G loss: 0.564211] [Elapsed time: 908.31s]
# [Epoch 41/200] [D loss: 0.312078] [G loss: 0.571260] [Elapsed time: 930.00s]
# [Epoch 42/200] [D loss: 0.053914] [G loss: 0.557791] [Elapsed time: 951.85s]
# [Epoch 43/200] [D loss: 0.189199] [G loss: 0.628175] [Elapsed time: 973.58s]
# [Epoch 44/200] [D loss: 0.185399] [G loss: 0.267645] [Elapsed time: 996.23s]
# [Epoch 45/200] [D loss: 0.048220] [G loss: 0.824884] [Elapsed time: 1018.04s]
# [Epoch 46/200] [D loss: 0.053805] [G loss: 0.772994] [Elapsed time: 1039.77s]
# [Epoch 47/200] [D loss: 0.123863] [G loss: 0.517282] [Elapsed time: 1061.45s]
# [Epoch 48/200] [D loss: 0.157141] [G loss: 0.598608] [Elapsed time: 1083.18s]
# [Epoch 49/200] [D loss: 0.251710] [G loss: 0.895667] [Elapsed time: 1104.86s]
# [Epoch 50/200] [D loss: 0.077292] [G loss: 0.218472] [Elapsed time: 1126.46s]
# [Epoch 51/200] [D loss: 0.099543] [G loss: 0.692862] [Elapsed time: 1148.24s]
# [Epoch 52/200] [D loss: 0.098878] [G loss: 0.738525] [Elapsed time: 1170.10s]
# [Epoch 53/200] [D loss: 0.068951] [G loss: 0.597795] [Elapsed time: 1192.77s]
# [Epoch 54/200] [D loss: 0.036790] [G loss: 0.617751] [Elapsed time: 1214.57s]
# [Epoch 55/200] [D loss: 0.054936] [G loss: 0.893588] [Elapsed time: 1236.17s]
# [Epoch 56/200] [D loss: 0.236987] [G loss: 0.407419] [Elapsed time: 1257.89s]
# [Epoch 57/200] [D loss: 0.137711] [G loss: 0.564908] [Elapsed time: 1279.86s]
# [Epoch 58/200] [D loss: 0.068873] [G loss: 0.382072] [Elapsed time: 1301.74s]
# [Epoch 59/200] [D loss: 0.056094] [G loss: 0.897780] [Elapsed time: 1323.64s]
# [Epoch 60/200] [D loss: 0.073474] [G loss: 0.750269] [Elapsed time: 1345.24s]
# [Epoch 61/200] [D loss: 0.059852] [G loss: 0.825146] [Elapsed time: 1368.24s]
# [Epoch 62/200] [D loss: 0.026781] [G loss: 0.728780] [Elapsed time: 1390.10s]
# [Epoch 63/200] [D loss: 0.024908] [G loss: 0.869543] [Elapsed time: 1411.86s]
# [Epoch 64/200] [D loss: 0.124025] [G loss: 0.654354] [Elapsed time: 1433.44s]
# [Epoch 65/200] [D loss: 0.015967] [G loss: 0.632133] [Elapsed time: 1455.34s]
# [Epoch 66/200] [D loss: 0.033957] [G loss: 0.379709] [Elapsed time: 1476.92s]
# [Epoch 67/200] [D loss: 0.143088] [G loss: 0.736403] [Elapsed time: 1498.44s]
# [Epoch 68/200] [D loss: 0.105254] [G loss: 0.687763] [Elapsed time: 1520.34s]
# [Epoch 69/200] [D loss: 0.043691] [G loss: 0.845386] [Elapsed time: 1543.23s]
# [Epoch 70/200] [D loss: 0.045159] [G loss: 0.792871] [Elapsed time: 1565.19s]
# [Epoch 71/200] [D loss: 0.053053] [G loss: 0.822538] [Elapsed time: 1586.71s]
# [Epoch 72/200] [D loss: 0.019996] [G loss: 0.743852] [Elapsed time: 1608.63s]
# [Epoch 73/200] [D loss: 0.019205] [G loss: 0.805305] [Elapsed time: 1630.39s]
# [Epoch 74/200] [D loss: 0.122350] [G loss: 0.580419] [Elapsed time: 1651.97s]
# [Epoch 75/200] [D loss: 0.113420] [G loss: 0.833814] [Elapsed time: 1673.69s]
# [Epoch 76/200] [D loss: 0.026501] [G loss: 0.509132] [Elapsed time: 1695.48s]
# [Epoch 77/200] [D loss: 0.120139] [G loss: 0.783939] [Elapsed time: 1718.18s]
# [Epoch 78/200] [D loss: 0.069431] [G loss: 0.901520] [Elapsed time: 1739.88s]
# [Epoch 79/200] [D loss: 0.047680] [G loss: 0.618267] [Elapsed time: 1761.74s]
# [Epoch 80/200] [D loss: 0.109347] [G loss: 0.695019] [Elapsed time: 1783.47s]
# [Epoch 81/200] [D loss: 0.297730] [G loss: 0.584789] [Elapsed time: 1805.02s]
# [Epoch 82/200] [D loss: 0.052975] [G loss: 0.806092] [Elapsed time: 1826.58s]
# [Epoch 83/200] [D loss: 0.127353] [G loss: 0.605959] [Elapsed time: 1848.65s]
# [Epoch 84/200] [D loss: 0.101991] [G loss: 0.670302] [Elapsed time: 1870.53s]
# [Epoch 85/200] [D loss: 0.134361] [G loss: 0.863165] [Elapsed time: 1893.59s]
# [Epoch 86/200] [D loss: 0.090806] [G loss: 0.887420] [Elapsed time: 1915.73s]
# [Epoch 87/200] [D loss: 0.281793] [G loss: 0.819328] [Elapsed time: 1937.73s]
# [Epoch 88/200] [D loss: 0.036686] [G loss: 0.434757] [Elapsed time: 1959.16s]
# [Epoch 89/200] [D loss: 0.075445] [G loss: 0.654632] [Elapsed time: 1980.89s]
# [Epoch 90/200] [D loss: 0.241085] [G loss: 0.878258] [Elapsed time: 2002.61s]
# [Epoch 91/200] [D loss: 0.132836] [G loss: 0.927995] [Elapsed time: 2024.15s]
# [Epoch 92/200] [D loss: 0.118504] [G loss: 0.786070] [Elapsed time: 2045.72s]
# [Epoch 93/200] [D loss: 0.029586] [G loss: 0.852202] [Elapsed time: 2068.45s]
# [Epoch 94/200] [D loss: 0.008212] [G loss: 0.505794] [Elapsed time: 2090.21s]
# [Epoch 95/200] [D loss: 0.070692] [G loss: 0.699851] [Elapsed time: 2111.77s]
# [Epoch 96/200] [D loss: 0.160903] [G loss: 0.849113] [Elapsed time: 2133.30s]
# [Epoch 97/200] [D loss: 0.026515] [G loss: 0.782885] [Elapsed time: 2155.02s]
# [Epoch 98/200] [D loss: 0.134821] [G loss: 0.913829] [Elapsed time: 2176.85s]
# [Epoch 99/200] [D loss: 0.200192] [G loss: 0.933876] [Elapsed time: 2198.15s]
# [Epoch 100/200] [D loss: 0.054215] [G loss: 0.778068] [Elapsed time: 2219.99s]
# [Epoch 101/200] [D loss: 0.013696] [G loss: 0.676762] [Elapsed time: 2242.55s]
# [Epoch 102/200] [D loss: 0.014432] [G loss: 0.959472] [Elapsed time: 2263.93s]
# [Epoch 103/200] [D loss: 0.022675] [G loss: 0.864401] [Elapsed time: 2285.91s]
# [Epoch 104/200] [D loss: 0.058639] [G loss: 0.683727] [Elapsed time: 2307.66s]
# [Epoch 105/200] [D loss: 0.080625] [G loss: 0.805877] [Elapsed time: 2329.35s]
# [Epoch 106/200] [D loss: 0.031458] [G loss: 0.751562] [Elapsed time: 2350.90s]
# [Epoch 107/200] [D loss: 0.094055] [G loss: 0.735035] [Elapsed time: 2372.73s]
# [Epoch 108/200] [D loss: 0.037303] [G loss: 0.799310] [Elapsed time: 2394.38s]
# [Epoch 109/200] [D loss: 0.217710] [G loss: 0.836792] [Elapsed time: 2417.20s]
# [Epoch 110/200] [D loss: 0.001337] [G loss: 0.727394] [Elapsed time: 2438.69s]
# [Epoch 111/200] [D loss: 0.050546] [G loss: 0.547991] [Elapsed time: 2460.37s]
# [Epoch 112/200] [D loss: 0.184712] [G loss: 0.936926] [Elapsed time: 2481.79s]
# [Epoch 113/200] [D loss: 0.053928] [G loss: 0.807620] [Elapsed time: 2503.36s]
# [Epoch 114/200] [D loss: 0.041555] [G loss: 0.431848] [Elapsed time: 2524.92s]
# [Epoch 115/200] [D loss: 0.293314] [G loss: 0.799126] [Elapsed time: 2546.36s]
# [Epoch 116/200] [D loss: 0.032283] [G loss: 0.583957] [Elapsed time: 2567.83s]
# [Epoch 117/200] [D loss: 0.106095] [G loss: 0.663596] [Elapsed time: 2590.74s]
# [Epoch 118/200] [D loss: 0.027896] [G loss: 0.664885] [Elapsed time: 2612.57s]
# [Epoch 119/200] [D loss: 0.244281] [G loss: 0.746191] [Elapsed time: 2634.37s]
# [Epoch 120/200] [D loss: 0.302574] [G loss: 0.871921] [Elapsed time: 2656.05s]
# [Epoch 121/200] [D loss: 0.153169] [G loss: 0.834366] [Elapsed time: 2677.73s]
# [Epoch 122/200] [D loss: 0.135956] [G loss: 0.863289] [Elapsed time: 2699.23s]
# [Epoch 123/200] [D loss: 0.205708] [G loss: 0.498854] [Elapsed time: 2720.64s]
# [Epoch 124/200] [D loss: 0.183929] [G loss: 0.496440] [Elapsed time: 2742.36s]
# [Epoch 125/200] [D loss: 0.098416] [G loss: 0.928583] [Elapsed time: 2765.30s]
# [Epoch 126/200] [D loss: 0.114246] [G loss: 0.668190] [Elapsed time: 2786.90s]
# [Epoch 127/200] [D loss: 0.079532] [G loss: 0.846203] [Elapsed time: 2808.60s]
# [Epoch 128/200] [D loss: 0.074049] [G loss: 0.184550] [Elapsed time: 2830.16s]
# [Epoch 129/200] [D loss: 0.053852] [G loss: 0.590375] [Elapsed time: 2851.52s]
# [Epoch 130/200] [D loss: 0.112009] [G loss: 0.908272] [Elapsed time: 2872.91s]
# [Epoch 131/200] [D loss: 0.213977] [G loss: 0.920547] [Elapsed time: 2894.77s]
# [Epoch 132/200] [D loss: 0.104943] [G loss: 0.663047] [Elapsed time: 2916.35s]
# [Epoch 133/200] [D loss: 0.170274] [G loss: 0.743762] [Elapsed time: 2939.16s]
# [Epoch 134/200] [D loss: 0.018119] [G loss: 0.823886] [Elapsed time: 2960.75s]
# [Epoch 135/200] [D loss: 0.009754] [G loss: 0.872198] [Elapsed time: 2982.67s]
# [Epoch 136/200] [D loss: 0.059399] [G loss: 0.925856] [Elapsed time: 3004.39s]
# [Epoch 137/200] [D loss: 0.152814] [G loss: 0.429939] [Elapsed time: 3025.53s]
# [Epoch 138/200] [D loss: 0.102620] [G loss: 0.846698] [Elapsed time: 3047.29s]
# [Epoch 139/200] [D loss: 0.095000] [G loss: 0.902003] [Elapsed time: 3068.87s]
# [Epoch 140/200] [D loss: 0.015550] [G loss: 0.953414] [Elapsed time: 3090.51s]
# [Epoch 141/200] [D loss: 0.016975] [G loss: 0.338470] [Elapsed time: 3113.36s]
# [Epoch 142/200] [D loss: 0.166402] [G loss: 0.748644] [Elapsed time: 3135.18s]
# [Epoch 143/200] [D loss: 0.134562] [G loss: 0.756333] [Elapsed time: 3156.70s]
# [Epoch 144/200] [D loss: 0.075676] [G loss: 0.943082] [Elapsed time: 3178.17s]
# [Epoch 145/200] [D loss: 0.038082] [G loss: 0.959576] [Elapsed time: 3200.06s]
# [Epoch 146/200] [D loss: 0.068045] [G loss: 0.958829] [Elapsed time: 3222.05s]
# [Epoch 147/200] [D loss: 0.147092] [G loss: 0.738226] [Elapsed time: 3244.05s]
# [Epoch 148/200] [D loss: 0.197117] [G loss: 0.913513] [Elapsed time: 3265.69s]
# [Epoch 149/200] [D loss: 0.149290] [G loss: 0.965247] [Elapsed time: 3288.73s]
# [Epoch 150/200] [D loss: 0.094218] [G loss: 0.780933] [Elapsed time: 3310.96s]
# [Epoch 151/200] [D loss: 0.251452] [G loss: 0.921816] [Elapsed time: 3332.89s]
# [Epoch 152/200] [D loss: 0.359294] [G loss: 0.914779] [Elapsed time: 3355.07s]
# [Epoch 153/200] [D loss: 0.053811] [G loss: 0.911847] [Elapsed time: 3377.34s]
# [Epoch 154/200] [D loss: 0.192256] [G loss: 0.418165] [Elapsed time: 3399.21s]
# [Epoch 155/200] [D loss: 0.303313] [G loss: 0.966277] [Elapsed time: 3420.84s]
# [Epoch 156/200] [D loss: 0.046171] [G loss: 0.885211] [Elapsed time: 3442.54s]
# [Epoch 157/200] [D loss: 0.017028] [G loss: 0.711384] [Elapsed time: 3465.50s]
# [Epoch 158/200] [D loss: 0.120441] [G loss: 0.563017] [Elapsed time: 3487.26s]
# [Epoch 159/200] [D loss: 0.059644] [G loss: 0.221488] [Elapsed time: 3508.64s]
# [Epoch 160/200] [D loss: 0.018554] [G loss: 0.772409] [Elapsed time: 3530.32s]
# [Epoch 161/200] [D loss: 0.073300] [G loss: 0.738725] [Elapsed time: 3552.21s]
# [Epoch 162/200] [D loss: 0.125619] [G loss: 0.571875] [Elapsed time: 3573.60s]
# [Epoch 163/200] [D loss: 0.005363] [G loss: 0.701943] [Elapsed time: 3595.48s]
# [Epoch 164/200] [D loss: 0.063781] [G loss: 0.883191] [Elapsed time: 3617.19s]
# [Epoch 165/200] [D loss: 0.097787] [G loss: 0.715049] [Elapsed time: 3639.88s]
# [Epoch 166/200] [D loss: 0.021668] [G loss: 0.750153] [Elapsed time: 3661.70s]
# [Epoch 167/200] [D loss: 0.104404] [G loss: 0.917423] [Elapsed time: 3683.42s]
# [Epoch 168/200] [D loss: 0.034123] [G loss: 0.883184] [Elapsed time: 3705.31s]
# [Epoch 169/200] [D loss: 0.197607] [G loss: 0.754404] [Elapsed time: 3726.86s]
# [Epoch 170/200] [D loss: 0.049656] [G loss: 0.348362] [Elapsed time: 3748.57s]
# [Epoch 171/200] [D loss: 0.095404] [G loss: 0.783560] [Elapsed time: 3770.21s]
# [Epoch 172/200] [D loss: 0.145965] [G loss: 0.744526] [Elapsed time: 3791.86s]
# [Epoch 173/200] [D loss: 0.047547] [G loss: 0.954917] [Elapsed time: 3814.55s]
# [Epoch 174/200] [D loss: 0.125474] [G loss: 0.905495] [Elapsed time: 3836.21s]
# [Epoch 175/200] [D loss: 0.071647] [G loss: 0.819972] [Elapsed time: 3857.98s]
# [Epoch 176/200] [D loss: 0.096701] [G loss: 0.888594] [Elapsed time: 3879.47s]
# [Epoch 177/200] [D loss: 0.083529] [G loss: 0.613092] [Elapsed time: 3901.09s]
# [Epoch 178/200] [D loss: 0.447145] [G loss: 0.859482] [Elapsed time: 3922.74s]
# [Epoch 179/200] [D loss: 0.036382] [G loss: 0.615492] [Elapsed time: 3944.45s]
# [Epoch 180/200] [D loss: 0.268279] [G loss: 0.659250] [Elapsed time: 3966.06s]
# [Epoch 181/200] [D loss: 0.030011] [G loss: 0.944372] [Elapsed time: 3988.95s]
# [Epoch 182/200] [D loss: 0.019619] [G loss: 0.467589] [Elapsed time: 4010.67s]
# [Epoch 183/200] [D loss: 0.148172] [G loss: 0.840785] [Elapsed time: 4032.27s]
# [Epoch 184/200] [D loss: 0.035124] [G loss: 0.894778] [Elapsed time: 4054.20s]
# [Epoch 185/200] [D loss: 0.061206] [G loss: 0.641695] [Elapsed time: 4075.84s]
# [Epoch 186/200] [D loss: 0.039745] [G loss: 0.975417] [Elapsed time: 4097.45s]
# [Epoch 187/200] [D loss: 0.173058] [G loss: 0.721073] [Elapsed time: 4119.00s]
# [Epoch 188/200] [D loss: 0.282056] [G loss: 0.681827] [Elapsed time: 4140.72s]
# [Epoch 189/200] [D loss: 0.019377] [G loss: 0.660231] [Elapsed time: 4163.58s]
# [Epoch 190/200] [D loss: 0.148955] [G loss: 0.355780] [Elapsed time: 4185.26s]
# [Epoch 191/200] [D loss: 0.274402] [G loss: 0.548846] [Elapsed time: 4207.04s]
# [Epoch 192/200] [D loss: 0.018489] [G loss: 0.832378] [Elapsed time: 4228.75s]
# [Epoch 193/200] [D loss: 0.104895] [G loss: 0.688683] [Elapsed time: 4250.24s]
# [Epoch 194/200] [D loss: 0.015882] [G loss: 0.914421] [Elapsed time: 4272.13s]
# [Epoch 195/200] [D loss: 0.132451] [G loss: 0.743610] [Elapsed time: 4293.66s]
# [Epoch 196/200] [D loss: 0.092904] [G loss: 0.941516] [Elapsed time: 4315.62s]
# [Epoch 197/200] [D loss: 0.107847] [G loss: 0.686213] [Elapsed time: 4338.30s]
# [Epoch 198/200] [D loss: 0.052596] [G loss: 0.839779] [Elapsed time: 4359.83s]
# [Epoch 199/200] [D loss: 0.110403] [G loss: 0.529118] [Elapsed time: 4381.43s]

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/custom/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# Out:
# Looking for images in ./results/custom/without_mask/*.png
# Looking for images in ./results/custom/without_mask/*.jpg
# Traceback (most recent call last):
#   File "./pytorch-frechet-inception-distance/fid.py", line 275, in <module>
#     images1 = load_images(options.path1)
#   File "./pytorch-frechet-inception-distance/fid.py", line 243, in load_images
#     first_image = cv2.imread(image_paths[0])
# IndexError: list index out of range

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/custom/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32
# Out:
# Looking for images in ./results/custom/with_mask/*.png
# Looking for images in ./results/custom/with_mask/*.jpg
# Traceback (most recent call last):
#   File "./pytorch-frechet-inception-distance/fid.py", line 275, in <module>
#     images1 = load_images(options.path1)
#   File "./pytorch-frechet-inception-distance/fid.py", line 243, in load_images
#     first_image = cv2.imread(image_paths[0])
# IndexError: list index out of range

# %%
# ./results/custom/ 폴더의 모든 파일을 results.zip라는 이름으로 압축
# !zip ./results.zip -r ./results/infogan/*
# Out:
#   adding: results/infogan/0.png (deflated 6%)
#   adding: results/infogan/10000.png (deflated 1%)
#   adding: results/infogan/1000.png (deflated 4%)
#   adding: results/infogan/10500.png (deflated 1%)
#   adding: results/infogan/11000.png (deflated 1%)
#   adding: results/infogan/11500.png (deflated 1%)
#   adding: results/infogan/12000.png (deflated 1%)
#   adding: results/infogan/12500.png (deflated 1%)
#   adding: results/infogan/13000.png (deflated 1%)
#   adding: results/infogan/13500.png (deflated 1%)
#   adding: results/infogan/14000.png (deflated 1%)
#   adding: results/infogan/14500.png (deflated 1%)
#   adding: results/infogan/15000.png (deflated 1%)
#   adding: results/infogan/1500.png (deflated 4%)
#   adding: results/infogan/15500.png (deflated 1%)
#   adding: results/infogan/16000.png (deflated 1%)
#   adding: results/infogan/16500.png (deflated 1%)
#   adding: results/infogan/17000.png (deflated 1%)
#   adding: results/infogan/17500.png (deflated 1%)
#   adding: results/infogan/18000.png (deflated 1%)
#   adding: results/infogan/18500.png (deflated 1%)
#   adding: results/infogan/19000.png (deflated 1%)
#   adding: results/infogan/19500.png (deflated 1%)
#   adding: results/infogan/20000.png (deflated 1%)
#   adding: results/infogan/2000.png (deflated 4%)
#   adding: results/infogan/20500.png (deflated 1%)
#   adding: results/infogan/21000.png (deflated 1%)
#   adding: results/infogan/21500.png (deflated 1%)
#   adding: results/infogan/22000.png (deflated 1%)
#   adding: results/infogan/22500.png (deflated 1%)
#   adding: results/infogan/23000.png (deflated 1%)
#   adding: results/infogan/23500.png (deflated 1%)
#   adding: results/infogan/24000.png (deflated 1%)
#   adding: results/infogan/24500.png (deflated 1%)
#   adding: results/infogan/25000.png (deflated 1%)
#   adding: results/infogan/2500.png (deflated 4%)
#   adding: results/infogan/25500.png (deflated 1%)
#   adding: results/infogan/26000.png (deflated 1%)
#   adding: results/infogan/26500.png (deflated 1%)
#   adding: results/infogan/27000.png (deflated 1%)
#   adding: results/infogan/27500.png (deflated 1%)
#   adding: results/infogan/28000.png (deflated 1%)
#   adding: results/infogan/28500.png (deflated 1%)
#   adding: results/infogan/29000.png (deflated 1%)
#   adding: results/infogan/29500.png (deflated 1%)
#   adding: results/infogan/30000.png (deflated 1%)
#   adding: results/infogan/3000.png (deflated 4%)
#   adding: results/infogan/30500.png (deflated 1%)
#   adding: results/infogan/31000.png (deflated 1%)
#   adding: results/infogan/31500.png (deflated 1%)
#   adding: results/infogan/32000.png (deflated 1%)
#   adding: results/infogan/32500.png (deflated 1%)
#   adding: results/infogan/33000.png (deflated 1%)
#   adding: results/infogan/33500.png (deflated 1%)
#   adding: results/infogan/34000.png (deflated 1%)
#   adding: results/infogan/34500.png (deflated 1%)
#   adding: results/infogan/35000.png (deflated 1%)
#   adding: results/infogan/3500.png (deflated 3%)
#   adding: results/infogan/35500.png (deflated 1%)
#   adding: results/infogan/36000.png (deflated 1%)
#   adding: results/infogan/36500.png (deflated 1%)
#   adding: results/infogan/37000.png (deflated 1%)
#   adding: results/infogan/37500.png (deflated 1%)
#   adding: results/infogan/38000.png (deflated 1%)
#   adding: results/infogan/38500.png (deflated 1%)
#   adding: results/infogan/39000.png (deflated 1%)
#   adding: results/infogan/39500.png (deflated 1%)
#   adding: results/infogan/40000.png (deflated 1%)
#   adding: results/infogan/4000.png (deflated 2%)
#   adding: results/infogan/40500.png (deflated 1%)
#   adding: results/infogan/41000.png (deflated 1%)
#   adding: results/infogan/41500.png (deflated 1%)
#   adding: results/infogan/42000.png (deflated 1%)
#   adding: results/infogan/42500.png (deflated 1%)
#   adding: results/infogan/43000.png (deflated 1%)
#   adding: results/infogan/43500.png (deflated 1%)
#   adding: results/infogan/44000.png (deflated 1%)
#   adding: results/infogan/44500.png (deflated 1%)
#   adding: results/infogan/45000.png (deflated 1%)
#   adding: results/infogan/4500.png (deflated 2%)
#   adding: results/infogan/45500.png (deflated 1%)
#   adding: results/infogan/46000.png (deflated 1%)
#   adding: results/infogan/46500.png (deflated 1%)
#   adding: results/infogan/47000.png (deflated 1%)
#   adding: results/infogan/47500.png (deflated 1%)
#   adding: results/infogan/48000.png (deflated 1%)
#   adding: results/infogan/48500.png (deflated 1%)
#   adding: results/infogan/49000.png (deflated 1%)
#   adding: results/infogan/49500.png (deflated 1%)
#   adding: results/infogan/50000.png (deflated 1%)
#   adding: results/infogan/5000.png (deflated 2%)
#   adding: results/infogan/500.png (deflated 3%)
#   adding: results/infogan/50500.png (deflated 1%)
#   adding: results/infogan/51000.png (deflated 1%)
#   adding: results/infogan/51500.png (deflated 1%)
#   adding: results/infogan/52000.png (deflated 1%)
#   adding: results/infogan/52500.png (deflated 1%)
#   adding: results/infogan/53000.png (deflated 1%)
#   adding: results/infogan/53500.png (deflated 1%)
#   adding: results/infogan/54000.png (deflated 1%)
#   adding: results/infogan/54500.png (deflated 1%)
#   adding: results/infogan/55000.png (deflated 1%)
#   adding: results/infogan/5500.png (deflated 2%)
#   adding: results/infogan/55500.png (deflated 1%)
#   adding: results/infogan/56000.png (deflated 1%)
#   adding: results/infogan/6000.png (deflated 1%)
#   adding: results/infogan/6500.png (deflated 2%)
#   adding: results/infogan/7000.png (deflated 1%)
#   adding: results/infogan/7500.png (deflated 1%)
#   adding: results/infogan/8000.png (deflated 1%)
#   adding: results/infogan/8500.png (deflated 1%)
#   adding: results/infogan/9000.png (deflated 1%)
#   adding: results/infogan/9500.png (deflated 1%)

# %%
# Google Colab으로부터 results.zip 압축 파일 다운로드
from google.colab import files

files.download('./results.zip')

# %% [markdown]
# * PPT에 들어갈 내용
#     1. 최종적으로 얻은 점수 (마스크 미착용 FID 점수 + 마스크 착용 FID 점수)
#     2. 좋은 결과를 만들기 위해 어떤 전략을 사용했는지, 그 이유는 무엇인지
#     3. 소스코드에서 핵심이 되는 부분 캡처 사진 및 설명
#     4. 자신의 GAN에서 생성된 이미지들 캡처 사진
# * 점수 판정 기준
#     * <b>FID의 점수 합이 가장 작은 팀</b>이 1등입니다.
#     * 마스크 미착용 FID 점수 = 171.67이고, 마스크 착용 FID 점수 = 114.97이라면?
#     * 최종 점수 = 171.67 + 114.97 = 286.64
# * 최종적으로 <b>팀 단위로 제출할 파일</b>은 다음과 같습니다.
#     1. PPT 파일: 사용한 모델과 최종적인 FID 점수에 대한 설명을 포함하기
#     2. Colab Notebook 파일: <b>[파일]</b> - <b>[다운로드]</b> - <b>[.ipynb 다운로드]</b>
#     3. 최종 결과 이미지(마스크 착용 1,000개 및 마스크 미착용 1,000개)가 포함된 압축 파일
# * 최종 결과 이미지는 다음과 같은 양식으로 압축 파일(.zip) 형태로 제출합니다.
#     * with_mask와 without_mask 이미지들이 서로 다른 폴더로 확실히 구분되어야 합니다.
#     * <b>PPT에 기록된 FID 점수와 동일한 점수</b>가 나오는 이미지여야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * GAN은 학습이 어려운 네트워크 중 하나입니다.
#     * 학습 자체가 안 되는 문제가 발생할 수 있습니다. (처음부터 D loss: 0.5, G loss: 1.0 고정되는 문제)
#     * 같은 레이블에 대하여 거의 똑같은 이미지만 생성될 수 있습니다. (mode collapse)
# * (Hint) 학습이 잘 안 되는 경우 배치 사이즈, learning rate, 아키텍처를 다시 확인하고 조절합니다.
# * FID 점수는 이미지 생성을 할 때마다 변경될 수 있습니다.
#     * 실제로 해당 FID 점수가 나왔는지 확인할 필요가 있으므로, 생성된 이미지 파일(총 2,000장)을 꼭 함께 제출합니다.
